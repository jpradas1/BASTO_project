# %%
import bson
import pandas as pd
import datetime
from bson.objectid import ObjectId
from itertools import groupby
from operator import itemgetter

# %%
# OPCION PARA ABRIR DESDE DATASET BSON

with open('test/datarows.bson', 'rb') as f:
    datarows = bson.decode_all(f.read())


with open('test/devices.bson', 'rb') as f:
    devices = bson.decode_all(f.read())

import bson

with open('test/animals.bson', 'rb') as f:
    animals = bson.decode_all(f.read())

# %%
#MERGE DATAROWS/DEVICES
# Crear un diccionario donde la clave es el "deviceMACAddress" y el valor es el diccionario completo del dispositivo correspondiente
device_dict = {}
for device in devices:
    device_dict[device["deviceMACAddress"]] = device

# Crear una nueva lista de datos fusionando los datos de datarows y devices
merged_data = []
for row in datarows:
    if row["UUID"] in device_dict:
        device_data = device_dict[row["UUID"]]
        merged_row = {**row, **device_data} # Fusionar los dos diccionarios en uno solo
        merged_data.append(merged_row)

# %%
#MERGE CON ANIMALS

for row in merged_data:
    animal_id = row.get('deviceAnimalID')
    animal = next((a for a in animals if a.get('_id') == animal_id), None)
    if animal:
        row['animal'] = animal
    else:
        row['animal'] = None

# %%
merged_data
# Out:
# [{'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-02-08T14:59:57',
#    'lat': -31.475927,
#    'lng': -64.19312783333334,
#    'gpsAlt': 456.8,
#    'gpsVel': 0.064,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 14, 59, 58, 512000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 14, 59, 58, 512000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:00:10.203Z',
#    'mac': '4347268646FA',
#    'battery': 100,
#    'temperature': 25.6,
#    'rssi': -87,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 0, 10, 210000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 0, 10, 210000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:02:52.360Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 99,
#    'temperature': 47.4,
#    'rssi': -72,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 2, 52, 372000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 2, 52, 372000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('6386616d3039cf00301d20e9'),
#   'dataRowData': {'timestamp': '2022-08-02T15:06:12.200Z',
#    'voltage': 4206,
#    'battery': 100,
#    'charge': 54},
#   'UUID': '0004A30B00F88969',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 6, 12, 211000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 6, 12, 211000),
#   '__v': 0,
#   'deviceType': 'PUNTO FIJO',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F88969',
#   'deviceAnimalID': ObjectId('638f559b47b80d0025f05f02'),
#   'animal': {'_id': ObjectId('638f559b47b80d0025f05f02'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': [],
#    'breed': 'DEFAULT-PUNTO-FIJO',
#    'createdAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'updatedAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'caravanaNumber': 'PUNTO_FIJO_4',
#    'birthDay': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'animalType': 'VACA',
#    'weight': 0,
#    'isPregmant': False,
#    '__v': 0}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:07:42.461Z',
#    'mac': 'DD383390BDD4',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -91,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 7, 42, 469000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 7, 42, 469000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:07:43.702Z',
#    'mac': '73DA3AA69DDA',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -82,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 7, 43, 705000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 7, 43, 705000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-02-08T15:10:05',
#    'lat': -31.476051166666668,
#    'lng': -64.19320833333333,
#    'gpsAlt': 472.2,
#    'gpsVel': 0.047,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 10, 6, 717000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 10, 6, 717000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:10:07.961Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -81,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 10, 7, 967000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 10, 7, 967000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-08-02T15:12:15.713Z',
#    'mac': 'A722E78120C0',
#    'battery': 100,
#    'temperature': 25.4,
#    'rssi': -94,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 12, 15, 718000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 12, 15, 718000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:12:29.148Z',
#    'mac': '3B415B321DDA',
#    'battery': 99,
#    'temperature': 47.4,
#    'rssi': -68,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 12, 29, 156000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 12, 29, 156000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:12:31.614Z',
#    'mac': '86395D2360F6',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -77,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 12, 31, 622000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 12, 31, 622000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:12:42.746Z',
#    'mac': 'DD383390BDD4',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -83,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 12, 42, 756000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 12, 42, 756000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-08-02T15:14:50.537Z',
#    'mac': '14D06B0EA2EE',
#    'battery': 100,
#    'temperature': 29.4,
#    'rssi': -95,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 14, 50, 540000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 14, 50, 540000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-08-02T15:14:51.767Z',
#    'mac': '4A18B8D1D4C0',
#    'battery': 99,
#    'temperature': 25.6,
#    'rssi': -93,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 14, 51, 775000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 14, 51, 775000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-02-08T15:15:10',
#    'lat': -32.85476516666667,
#    'lng': -63.64277883333333,
#    'gpsAlt': 224.1,
#    'gpsVel': 0.018,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 15, 12, 159000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 15, 12, 159000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:15:14.205Z',
#    'mac': 'F4249D6F51D4',
#    'battery': 99,
#    'temperature': 47.8,
#    'rssi': -90,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 15, 14, 210000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 15, 14, 210000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('6386616d3039cf00301d20e9'),
#   'dataRowData': {'timestamp': '2022-08-02T15:16:12.217Z',
#    'voltage': 4204,
#    'battery': 100,
#    'charge': 42},
#   'UUID': '0004A30B00F88969',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 16, 12, 222000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 16, 12, 222000),
#   '__v': 0,
#   'deviceType': 'PUNTO FIJO',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F88969',
#   'deviceAnimalID': ObjectId('638f559b47b80d0025f05f02'),
#   'animal': {'_id': ObjectId('638f559b47b80d0025f05f02'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': [],
#    'breed': 'DEFAULT-PUNTO-FIJO',
#    'createdAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'updatedAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'caravanaNumber': 'PUNTO_FIJO_4',
#    'birthDay': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'animalType': 'VACA',
#    'weight': 0,
#    'isPregmant': False,
#    '__v': 0}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:16:29.645Z',
#    'voltage': 3811,
#    'battery': 61,
#    'charge': 73},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 16, 29, 650000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 16, 29, 650000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:27.701Z',
#    'mac': 'D1A5E6927CD1',
#    'battery': 100,
#    'temperature': 28.3,
#    'rssi': -97,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 27, 704000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 27, 704000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:30.160Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -72,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 30, 166000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 30, 166000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:32.413Z',
#    'mac': '86395D2360F6',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -76,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 32, 419000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 32, 419000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:34.652Z',
#    'mac': '4347268646FA',
#    'battery': 100,
#    'temperature': 25.6,
#    'rssi': -87,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 34, 657000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 34, 657000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:42.851Z',
#    'mac': 'DD383390BDD4',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -82,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 42, 854000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 42, 854000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:17:51.256Z',
#    'mac': '73DA3AA69DDA',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -78,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 17, 51, 259000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 17, 51, 259000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-02-08T15:20:32',
#    'lat': -31.475896166666665,
#    'lng': -64.19314266666666,
#    'gpsAlt': 0,
#    'gpsVel': 0.066,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 20, 33, 459000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 20, 33, 459000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:22:30.477Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -81,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 22, 30, 482000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 22, 30, 482000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:22:31.992Z',
#    'mac': '86395D2360F6',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -79,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 22, 31, 997000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 22, 31, 997000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:22:33.513Z',
#    'mac': '4347268646FA',
#    'battery': 100,
#    'temperature': 25.6,
#    'rssi': -89,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 22, 33, 516000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 22, 33, 516000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:24:59.467Z',
#    'mac': '3B415B321DDA',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -82,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 24, 59, 471000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 24, 59, 471000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:25:06.523Z',
#    'mac': '73DA3AA69DDA',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -73,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 25, 6, 528000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 25, 6, 528000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:25:20.593Z',
#    'mac': 'DD383390BDD4',
#    'battery': 100,
#    'temperature': 47.6,
#    'rssi': -82,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 25, 20, 597000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 25, 20, 597000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('6386616d3039cf00301d20e9'),
#   'dataRowData': {'timestamp': '2022-08-02T15:26:12.123Z',
#    'voltage': 4206,
#    'battery': 100,
#    'charge': 35},
#   'UUID': '0004A30B00F88969',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 26, 12, 130000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 26, 12, 130000),
#   '__v': 0,
#   'deviceType': 'PUNTO FIJO',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F88969',
#   'deviceAnimalID': ObjectId('638f559b47b80d0025f05f02'),
#   'animal': {'_id': ObjectId('638f559b47b80d0025f05f02'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': [],
#    'breed': 'DEFAULT-PUNTO-FIJO',
#    'createdAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'updatedAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'caravanaNumber': 'PUNTO_FIJO_4',
#    'birthDay': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'animalType': 'VACA',
#    'weight': 0,
#    'isPregmant': False,
#    '__v': 0}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:26:29.595Z',
#    'voltage': 3796,
#    'battery': 59,
#    'charge': 29},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 26, 29, 598000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 26, 29, 598000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:27:38.006Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 98,
#    'temperature': 47.4,
#    'rssi': -79,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 27, 38, 9000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 27, 38, 9000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:27:40.266Z',
#    'mac': '86395D2360F6',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -79,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 27, 40, 271000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 27, 40, 271000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('6386616d3039cf00301d20e9'),
#   'dataRowData': {'timestamp': '2022-02-08T15:29:01',
#    'lat': -32.863689,
#    'lng': -63.63591566666667,
#    'gpsAlt': 0,
#    'gpsVel': 0.034,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F88969',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 29, 3, 480000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 29, 3, 480000),
#   '__v': 0,
#   'deviceType': 'PUNTO FIJO',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F88969',
#   'deviceAnimalID': ObjectId('638f559b47b80d0025f05f02'),
#   'animal': {'_id': ObjectId('638f559b47b80d0025f05f02'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': [],
#    'breed': 'DEFAULT-PUNTO-FIJO',
#    'createdAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'updatedAt': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'caravanaNumber': 'PUNTO_FIJO_4',
#    'birthDay': datetime.datetime(2022, 12, 6, 14, 45, 47, 839000),
#    'animalType': 'VACA',
#    'weight': 0,
#    'isPregmant': False,
#    '__v': 0}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:29:59.619Z',
#    'mac': '3B415B321DDA',
#    'battery': 100,
#    'temperature': 47.5,
#    'rssi': -78,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 29, 59, 625000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 29, 59, 625000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:30:20.769Z',
#    'mac': 'DD383390BDD4',
#    'battery': 100,
#    'temperature': 47.6,
#    'rssi': -84,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 30, 20, 772000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 30, 20, 772000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-02-08T15:20:32',
#    'lat': -31.475896166666665,
#    'lng': -64.19314266666666,
#    'gpsAlt': 0,
#    'gpsVel': 0.066,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 30, 41, 942000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 30, 41, 942000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-02-08T15:30:40',
#    'lat': -31.476018833333335,
#    'lng': -64.19308233333334,
#    'gpsAlt': 450.9,
#    'gpsVel': 0.072,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 30, 44, 205000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 30, 44, 205000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-08-02T15:32:21.941Z',
#    'mac': 'D9F4EE08E1DA',
#    'battery': 100,
#    'temperature': 27.7,
#    'rssi': -79,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 32, 21, 945000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 32, 21, 945000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:32:34.037Z',
#    'mac': '4347268646FA',
#    'battery': 100,
#    'temperature': 25.6,
#    'rssi': -89,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 32, 34, 40000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 32, 34, 40000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
#    'createdAt': datetime.datetime(2022, 7, 19, 17, 27, 46, 820000),
#    'updatedAt': datetime.datetime(2023, 2, 10, 18, 40, 12, 193000),
#    '__v': 0,
#    'animalTags': ['VIEJA']}},
#  {'_id': ObjectId('62f52bee401c510025e01f29'),
#   'dataRowData': {'timestamp': '2022-08-02T15:32:38.310Z',
#    'mac': '7F93E1ED74CA',
#    'battery': 100,
#    'temperature': 47.4,
#    'rssi': -73,
#    'accelerometer': '000000000000',
#    'firmwareVersion': '0000'},
#   'UUID': '0004A30B00F82BD2',
#   'dataRowType': 'BEACON',
#   'createdAt': datetime.datetime(2022, 8, 2, 15, 32, 38, 322000),
#   'updatedAt': datetime.datetime(2022, 8, 2, 15, 32, 38, 322000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2.0.0',
#   'deviceMACAddress': '0004A30B00F82BD2',
#   'deviceAnimalID': ObjectId('62d6e9920408c608acb6fdd0'),
#   'animal': {'_id': ObjectId('62d6e9920408c608acb6fdd0'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'caravanaNumber': 'CAR9',
#    'animalType': 'VACA',
#    'weight': 500,
#    'birthDay': datetime.datetime(2022, 7, 18, 0, 0),
#    'breed': 'SIMBRAH',
#    'isPregmant': False,
#    'dateOfBirth': None,
#    'observations': '',
# ...
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-01-22T12:31:43.832Z',
#    'voltage': 4038,
#    'battery': 73,
#    'charge': -16},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 1, 22, 12, 31, 43, 834000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 12, 31, 43, 834000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T12:45:42',
#    'lat': -32.853821833333335,
#    'lng': -63.64558483333333,
#    'gpsAlt': 227.4,
#    'gpsVel': 0.019,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 12, 45, 55, 141000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 12, 45, 55, 141000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-01-22T12:46:46.187Z',
#    'voltage': 4038,
#    'battery': 73,
#    'charge': -24},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 1, 22, 12, 46, 46, 188000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 12, 46, 46, 188000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:16:10',
#    'lat': -32.853841333333335,
#    'lng': -63.645627,
#    'gpsAlt': 0,
#    'gpsVel': 0.005,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 16, 20, 757000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 16, 20, 757000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:16:27',
#    'lat': -32.8538,
#    'lng': -63.64558533333334,
#    'gpsAlt': 234.8,
#    'gpsVel': 0.036,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 16, 36, 167000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 16, 36, 167000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-01-22T13:41:54.492Z',
#    'voltage': 4040,
#    'battery': 73,
#    'charge': -7},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 41, 54, 494000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 41, 54, 494000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:42:12',
#    'lat': -32.85380333333333,
#    'lng': -63.64559766666667,
#    'gpsAlt': 230.9,
#    'gpsVel': 0.012,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 42, 25, 823000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 42, 25, 823000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:42:17',
#    'lat': -32.85380333333333,
#    'lng': -63.64559633333333,
#    'gpsAlt': 230.8,
#    'gpsVel': 0.001,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 42, 30, 217000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 42, 30, 217000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:47:27',
#    'lat': -32.853805333333334,
#    'lng': -63.64559083333333,
#    'gpsAlt': 227.7,
#    'gpsVel': 0.008,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 47, 46, 339000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 47, 46, 339000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:57:17',
#    'lat': -32.853785,
#    'lng': -63.64557933333333,
#    'gpsAlt': 240.5,
#    'gpsVel': 0.014,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 57, 20, 90000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 57, 20, 90000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T14:23:07',
#    'lat': -32.853807833333335,
#    'lng': -63.64559116666667,
#    'gpsAlt': 234.8,
#    'gpsVel': 0.01,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 14, 24, 5, 235000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 14, 24, 5, 235000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T14:23:17',
#    'lat': -32.85380766666667,
#    'lng': -63.645593166666664,
#    'gpsAlt': 232.5,
#    'gpsVel': 0.007,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 14, 24, 5, 849000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 14, 24, 5, 849000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-22-01T13:16:47',
#    'lat': -32.853801833333335,
#    'lng': -63.645590166666665,
#    'gpsAlt': 230.2,
#    'gpsVel': 0.009,
#    'gpsFixed': 1},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'GPS',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 17, 9, 873000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 17, 9, 873000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  {'_id': ObjectId('638660af3039cf00301d200d'),
#   'dataRowData': {'timestamp': '2022-01-22T13:51:58.292Z',
#    'voltage': 4047,
#    'battery': 74,
#    'charge': 4},
#   'UUID': '0004A30B00F825B7',
#   'dataRowType': 'BATTERY',
#   'createdAt': datetime.datetime(2022, 1, 22, 13, 51, 58, 293000),
#   'updatedAt': datetime.datetime(2022, 1, 22, 13, 51, 58, 293000),
#   '__v': 0,
#   'deviceType': 'COLLAR',
#   'deviceFirmwareVersion': '2222',
#   'deviceMACAddress': '0004A30B00F825B7',
#   'deviceAnimalID': ObjectId('638660af3039cf00301d200e'),
#   'animal': {'_id': ObjectId('638660af3039cf00301d200e'),
#    'animalSettlement': [ObjectId('620e6e5e60543d0026a01f0e')],
#    'animalTags': ['LACTANCIA'],
#    'breed': 'JERSEY',
#    'createdAt': datetime.datetime(2022, 11, 29, 19, 42, 40, 20000),
#    'updatedAt': datetime.datetime(2023, 3, 7, 12, 52, 14, 799000),
#    'caravanaNumber': 'COLLAR_3',
#    'birthDay': datetime.datetime(2022, 11, 29, 0, 0),
#    'animalType': 'VACA',
#    'weight': 151,
#    'isPregmant': False,
#    '__v': 0,
#    'dateOfBirth': None,
#    'observations': None}},
#  ...]

# %%
#TO DATE TIME

for d in merged_data:
    timestamp_str = d['dataRowData']['timestamp']
    try:
        timestamp_obj = pd.to_datetime(timestamp_str)
    except ValueError:
        try:
            timestamp_obj = pd.to_datetime(timestamp_str, format='%Y-%d-%mT%H:%M:%S')
        except ValueError:
            timestamp_obj = timestamp_obj
    d['dataRowData']['timestamp'] = timestamp_obj

# %%
def gps(desired_id: str, date_str: str):
    # Convertir la fecha en un objeto datetime.date
    date_obj = datetime.datetime.strptime(date_str, "%Y, %m, %d").date()
    
    # Convertir el string de desired_id en un objeto ObjectId
    desired_id_obj = ObjectId(desired_id)
    
    #FILTRO POR ID CAMPO y DATAROWTYPE = GPS
    gps_data = [element for element in merged_data if element.get("dataRowType") == "GPS" and desired_id_obj in element["animal"]["animalSettlement"]]
    #FILTRO POR DIA
    filtered_data = [d for d in gps_data if d["dataRowData"]["timestamp"] == date_obj]


    # Contar UUIDs/COLLARES únicos ese día
    unique_uuids = set(d['UUID'] for d in filtered_data)
    

    # CREO DICCIONARIO KEYS= COLLAR, INFO LAT LONG DATE
    gps_data_by_uuid = {}
    for uuid in unique_uuids:
        filtered_gps_data_animal = [d for d in filtered_data if d['UUID'] == uuid]
        gps_data_dict = {'timestamp': [], 'latitud': [], 'longitud': []}
        for d in filtered_gps_data_animal:
            gps_data_dict['timestamp'].append(d['dataRowData']['timestamp'])
            gps_data_dict['latitud'].append(d['dataRowData']['lat'])
            gps_data_dict['longitud'].append(d['dataRowData']['lng'])
        gps_data_by_uuid[uuid] = gps_data_dict
 

    
    return (gps_data_by_uuid)


#TRAE LISTA DE COLLARES DENTRO DEL CAMPO, DENTRO DE CADA COLLAR SE ENCUENTRA UN DICCIONARIO CON LOS DATOS DATE,LAT,LNG. INGRESAR PARAMETROS EN FORMATO STRING
# ID CAMPO EJ = "620e6e5e60543d0026a01f0e"
# FECHA STR = EJ "2022, 9, 21"

# %%
collardicc = gps("620e6e5e60543d0026a01f0e","2022, 9, 21")
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_11156\1221156100.py:11: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   filtered_data = [d for d in gps_data if d["dataRowData"]["timestamp"] == date_obj]

# %%
collardicc.keys()
# Out:
# dict_keys(['0004A30B00F825B7', '0004A30B00EE959D', '0004A30B00F88969', '0004A30B00F82E9C', '0004A30B00F82BD2'])

# %%
type(collardicc["0004A30B00F825B7"])
# Out:
# dict

# %%
print(collardicc["0004A30B00F825B7"]["timestamp"][0])

print(collardicc["0004A30B00F825B7"]["latitud"][0])

print(collardicc["0004A30B00F825B7"]["longitud"][0])
# Out:
# 2022-09-21 00:53:02
# -32.85475433333333
# -63.6427645

# %%
def caravanas(desired_id: str, date_str: str):
    # Convertir la fecha en un objeto datetime.date
    date_obj = datetime.datetime.strptime(date_str, "%Y, %m, %d").date()

    # Convertir el string de desired_id en un objeto ObjectId
    desired_id_obj = ObjectId(desired_id)

    # Filtrar por ID CAMPO y DATAROWTYPE = CARAVANA
    beacon_data = [element for element in merged_data if element.get("dataRowType") == "BEACON" and desired_id_obj in element["animal"]["animalSettlement"]]

    # Filtrar por día
    filtered_dataB = [d for d in beacon_data if d["dataRowData"]["timestamp"].date() == date_obj]

    
    # Contar UUIDs/COLLARES únicos ese día
    unique_uuids = set(d['UUID'] for d in filtered_dataB)

    collar_data = {}
    collar_list = set(d['UUID'] for d in filtered_dataB)

    for collar in collar_list:
        #FILTRO POR COLLAR
        beacon_data1 = [element for element in filtered_dataB if element.get("UUID") == collar]
        
        data_list = []
        
        for d in beacon_data1:
            date = d['dataRowData']['timestamp']
            mac = d['dataRowData']['mac']
            data_list.append({'date': date, 'mac': mac})
        
        
        # Ordenar la lista por fecha
        data_list_sorted = sorted(data_list, key=itemgetter('date'))
        
        # Agrupar por hora
        grouped_data = []
        for hour, group in groupby(data_list_sorted, lambda x: x['date'].strftime('%Y-%m-%d %H')):
            macs = set()
            for item in group:
                macs.add(item['mac'])
            grouped_data.append({'hour': hour, 'macs': macs})
        
        collar_data[collar] = grouped_data

    return collar_data


#TRAE CARAVANAS EN BASE A COLLARES POR ID CAMPO Y FECHA

# %%
collardicc1 = caravanas("620e6e5e60543d0026a01f0e","2022, 9, 21")

# %%
collardicc1.keys()
# Out:
# dict_keys(['0004A30B00EE959D', '0004A30B00F82BD2', '0004A30B00F82E9C', '0004A30B00F825B7'])

# %%
collardicc1["0004A30B00F825B7"]
# Out:
# [{'hour': '2022-09-21 12', 'macs': {'A7AA2D0FF0F3'}},
#  {'hour': '2022-09-21 18', 'macs': {'7F93E1ED74CA'}},
#  {'hour': '2022-09-21 20', 'macs': {'86395D2360F6'}}]

# %%
collardicc1["0004A30B00F825B7"][1]
# Out:
# {'hour': '2022-09-21 18', 'macs': {'7F93E1ED74CA'}}

# %%
collardicc1["0004A30B00F82E9C"][0]["macs"]
# Out:
# {'1D96FE9FFEF4', '3B415B321DDA', 'F356641DB6D3'}

# %%
import bson
from bson import ObjectId

# %%
with open('test/settlements.bson', 'rb') as f:
    settlements = bson.decode_all(f.read())

with open('test/plots.bson', 'rb') as f:
    plots = bson.decode_all(f.read())

# %%
def obtener_geopointsp(desired_id: str):
    
    # Convertir el string de desired_id en un objeto ObjectId
    desired_id_obj = ObjectId(desired_id)
    
    # Obtener lista de IDs de parcelas
    lista_plots = []
    for a in settlements:
        if a["_id"] == desired_id_obj:
            lista_plots.extend(a["plots"])
            
    # Crear lista para guardar los resultados
    lista_resultados = []
    
    # Recorrer lista de IDs de parcelas y buscar cada una en la colección de parcelas
    for id_parcela in lista_plots:  # La lista de IDs está dentro de otra lista
        for plot in plots:
            if plot["_id"] == id_parcela:
                # Obtener geopoints de la parcela y agregarlos a la lista de resultados
                geopoints = plot["geoPoints"]
                lista_resultados.append({"_id": plot["_id"], "geopoints": geopoints})
    
    # Devolver lista de resultados
    return lista_resultados



#TRAE EN BASE A ID CAMPO, LA CANTIDAD DE LOTES QUE LO CONFORMAN, Y SUS GEOPOINTS

# %%
geopoints = obtener_geopointsp("620e6e5e60543d0026a01f0e")

# %%
geopoints[0]["_id"]
# Out:
# ObjectId('63b55f4b973f9f35c0c5b37d')

# %%
geopoints[1]["geopoints"][0]["lng"]
# Out:
# -63.64061

# %%
geopoints[3]  #CADA ELEMENTO ES UN PLOT
# Out:
# {'_id': ObjectId('63e4f73507c91900306018e6'),
#  'geopoints': [{'_id': ObjectId('63e4f73507c91900306018e7'),
#    'lat': -32.848689076537156,
#    'lng': -63.63217129296387},
#   {'_id': ObjectId('63e4f73507c91900306018e8'),
#    'lat': -32.85470979619781,
#    'lng': -63.633501668635255},
#   {'_id': ObjectId('63e4f73507c91900306018e9'),
#    'lat': -32.85470979619781,
#    'lng': -63.629253049555665},
#   {'_id': ObjectId('63e4f73507c91900306018ea'),
#    'lat': -32.85225829498449,
#    'lng': -63.62732185906494},
#   {'_id': ObjectId('63e4f73507c91900306018eb'),
#    'lat': -32.84915776997614,
#    'lng': -63.62710728234375}]}
